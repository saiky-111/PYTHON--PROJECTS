# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd  # Pandas is used for data manipulation and analysis
import matplotlib.pyplot as plt  # Matplotlib is used for creating static, animated, and interactive visualizations in Python
import seaborn as sns  # Seaborn is built on top of Matplotlib and provides a high-level interface for drawing attractive statistical graphics
import warnings  # Warnings library to manage warnings

# Ignore any warning messages
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading The Dataset

# %%
df = pd.read_csv('hotel_bookings.csv')  #since, it is in csv format, so calling read_csv function

# %% [markdown]
# # Exploratory Data Analysis and Data Cleaning

# %%
df.head() # It will return top 5 rows, if we don't pass any number.
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail(10) # It will return last 10 rows from the table
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %%
df.shape # It will tell us how many number of rows and columns are present in our dataset, 
# also this dataset has been filtered (some columns have been removed earlier) such that all personal details of the persons are not shared.
# Out:
# (119390, 32)

# %%
df.columns # names of the columns in our dataset
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info() # checking the data type of the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#Columns Like Children, Country, Company have missing values , (means no of rows are less).
# the column reservation_status_date is in object form, but we need to convert it to date time.
#(a date column have to be cnverted to date time column)

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y', dayfirst=True)
# changing the column datatype from object to datetime
# Here, after changing it to datetime format, we are again saving it to the same column.

# ** Since, in the dataset, the dates we somewhat mixed, so to bring it to a Standard Format.
# So, we are Specifying the date format explicitly using the format parameter and set dayfirst=True
# since the dates are in day/month/year format.

# dayfirst=True: Indicates that the day comes before the month in the date strings. 
# This is important for correct parsing when the date format isn't the default (which is month/day/year).

# %%
df.info() # Checking that it (the column) has been converted to date time format successfully.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# By default, only shows the numerical columns.
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.482918     106.863097           0.707476
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
df.describe(include = 'object')
# in the datatable, some 'object' datatype is there in some columns, which are nothing but, Categorical Columns.
# We can see how many unique values are there in the categorical columns
# So, we will use describe() function, which by default is used for numerical columns. 
# But, if we include 'object' then it will give summary statistics of object column.
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
# We can see the number of unique values in each column , also we can see the total number of values in each column.

# %%
for col in df.describe(include = 'object').columns:
    print(col)
    print(df[col].unique())
    print('-'*50) # Making it visible , by adding a line in between.
# By running a for loop , we can see what are these values 
# So, running a for loop in the columns, which are of object type.
# So, first we are printing the names of the columns of object type, then the unique values under each columns
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
df.isnull().sum()
# Finding Missing Values
# it returns the name of the columns, and it returns the number of values which are missing, in the column.
# it returns the column values which are missing
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# the columns which have huge number of values missing, we will remove them. Like: agent, company. Since , we can't handle them.
# Since, in country , out of 100000 rows, only about 488 values are missing, so we can drop them.
# So, using df.drop function to remove the columns.(we can also remove rows from this function)
# Since, we are removing a column , so we'll have to write: axis = 1
# Using inplace =  True , since we are changing the original dataframe in it's place.

# %%
df.drop(['company', 'agent'] , axis = 1 , inplace = True)  # removing the columns : company, agent

# %%
df.dropna(inplace = True)  # Using this df.dropna to remove the rows with missing values.

# %%
df.isnull().sum() # So, removed all missing values from data
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe() # Gives the Summary Statistics of the Numerical Columns
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
# There are many many outliers in the data above.
# Like in the childern's table, babies table 10 isn't possible.
# But, we are not removing these outliers. Since, we don't have any use of these columns here.
# adr = average daily rate is: maximum 5400, which is very high. So, we'll have to remove this outlier. Since, we'll perform analysis on it.

# %%
df['adr'].plot(kind = 'box')   # Watching the outlier, how much difference of values it gives.
# Out:
# <Axes: >

# %%
df = df[df['adr']<5000]  # Means we are removing values less than 5000 in adr.

# %%
df['adr'].plot(kind = 'box') # Now, it's good.
# Out:
# <Axes: >

# %% [markdown]
# # Data Analysis and Visualizations

# %%
# We'll analyze, in dataset, amount of reservations which has been cancelled , and, how many, have not been cancelled.
# We'll see it's percentage, if it's a normal issue or a major issue.

# %%
cancelled_perc = df['is_canceled'].value_counts(normalize = True)
cancelled_perc
# Value Count is such a function , which returns the category name and how many times it is present in the column.
# And if we do Normalize = True , it will return a percentage.
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64

# %%
# So, 62.8 % reservations are not cancelled.
# Around, 37.1 % reservations stands cancelled.(almost half)  But, it is way much higher. 5-10% would have been manageable.

# %%
print(cancelled_perc)

plt.figure(figsize = (5,4)) # creating a plot, size of the plot is given by figsize
plt.title('Reservation Status Count')  # Title of the plot

plt.bar(['Not Canceled','Canceled'], df['is_canceled'].value_counts(), edgecolor = 'k', width = 0.7)
plt.show() # Visulazing the plot
# Plotting a bar graph , since it's a categorical data, we'll present some count of it.
# in the x-axis: 'Not Canceled','Canceled' : these will be plotted, and the value will come from as calculated in line 86
# and we are removing normalize = true as, e want exact count here.
# Using:  edgecolor = 'k', width = 0.7  to beautify the plot
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64

# %%
# So, we can see it's a major(or big) problem for Hotels.

# %%
# Now we'll see: Whose cancelletion rate is more, and whose cancelletion rate is less

# %%
plt.figure(figsize=(8, 4)) 
ax1 = sns.countplot(x='hotel', hue='is_canceled', data=df, palette='Blues')
legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1, 1)) 
plt.title('Reservation Status In Different Hotels', size=20)
plt.xlabel('Hotel')
plt.ylabel('Number Of Reservations')
plt.legend(['Not canceled', 'Canceled'])  
plt.show()

# So, we're using seaborn library : sns count plot for that
## All these are just to beautify the vizualization

# %%
# The difference between the top of the bargraphs of Resort and City Hotel are different.
# In city Hotels, calcellations are way too much
